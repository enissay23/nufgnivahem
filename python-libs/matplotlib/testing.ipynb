# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.9.0'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpts = np.array([0, 1, 2, 3])
ypts = np.array([3, 8, 1, 10])

plt.plot(xpts, ypts, 'o-.b', mfc='k', mec='k')
plt.show()
